# %% [markdown]
# # 15.2.8 Beam search
#
# <div><table><tr>
# <td style="border: none; text-align:left; vertical-align:top;" width=700>
#
# **Greedy decoding:**
#
# En cada $t$, calculamos:
# $$\hat{y}_t=\operatorname*{argmax}\limits_y\;p(y_t=y\mid\hat{\boldsymbol{y}}_{1:t-1},\boldsymbol{x})$$
#
# *Ejemplo:* $\;\boldsymbol{x}=\mathtt{I\;am\;a\;student}$
# * $y_1=\operatorname*{argmax}_y\;p(y_1=y\mid\hat{\boldsymbol{y}}_{1:0}=\mathtt{\_},\boldsymbol{x})=\mathtt{A}$
# * $y_2=\operatorname*{argmax}_y\;p(y_2=y\mid\hat{\boldsymbol{y}}_{1:1}=\mathtt{moi},\boldsymbol{x})=\mathtt{B}$
# * $y_3=\operatorname*{argmax}_y\;p(y_3=y\mid\hat{\boldsymbol{y}}_{1:2}=\mathtt{moi\,sus},\boldsymbol{x})=\mathtt{C}$
# * $y_4=\operatorname*{argmax}_y\;p(y_4=y\mid\hat{\boldsymbol{y}}_{1:3}=\mathtt{moi\,sus\,étudiant},\boldsymbol{x})=\mathtt{<eos>}$
#
# </td><td style="border: none;"><img src="Figure_15.8_B_crop.png" width=300></td>
# </tr></table></div>
#
# <div><table><tr>
# <td style="border: none; text-align:left; vertical-align:top;" width=300>
#
# **Secuencia MAP:**
#
# $$\boldsymbol{y}_{1:T}^*=\operatorname*{argmax}\limits_{\boldsymbol{y}_{1:T}}\;p(\boldsymbol{y}_{1:T}\mid\boldsymbol{x})$$
#
# *Ejemplo:*
# * Greedy: $\;0.048\;\mathtt{ABC<eos>}$
# * MAP: $\;0.054\;\mathtt{ACB<eos>}$
#
# *Complejidad:* $\;O(V^T)\;$ con $V$ palabras
#
# </td>
# <td style="border: none;"><img src="Figure_15.12_A.png" width=350></td>
# <td style="border: none;"><img src="Figure_15.12_B.png" width=350></td>
# </tr></table></div>
#
# <br><br>
#
# <div><table><tr>
# <td style="border: none; text-align:left; vertical-align:top;" width=400>
#
# **Beam search:**
#
# Selecciona los $K$ mejores tras generar todos los hijos de los nodos vivos actuales ($VK$ a partir de $t=2$)
#
# *Variantes de beam search:*
# * *Stochastic beam search*
# * *Diverse beam search*
#
# </td>
# <td style="border: none;"><img src="Figure_15.13.png" width=600></td>
# </tr></table></div>
